# %%
import asyncio
import requests
import aiofiles
import httpx
from bs4 import BeautifulSoup
from tqdm import tqdm

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/113.0"
}

# %%
soup = BeautifulSoup(
    requests.get(
        "https://www.homepornking.com/video/7/349/17442/872075",
        headers=headers,
    ).text,
    "html.parser",
)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
# document.cookie='ttsref=noref; domain=.homepornking.com; path=/;';
#
# document.cookie='ach0=1521; domain=.homepornking.com; path=/;';
#
# pe971=0;
# if (Math.tan(79) > 0)  pe206=(2047-99); else pe206=(2051+173);
# pe971+=pe206;
# if (Math.cos(34) > 0)  pe129=(2933-94); else pe129=(2844+78);
# pe971+=pe129;
# if (Math.tan(138) > 0)  pe566=(477299*145); else pe566=(477260/98);
# pe971+=pe566;
#
# document.cookie = 'ach='+pe971+'; domain=.homepornking.com; path=/;';
#
# </script>
# <title>Amateur Russian Homemade</title>
# <meta content="4 min - Free amateur russian home made, porn video" name="description"/>
# <meta content="EN" name="Language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.homepornking.com/video/7/349/17442/872075/" rel="canonical"/>
# ...

# %%
[s["src"] for s in soup.find_all("source") if s.has_attr("src") and s["src"]][
    0
]
# Out:
# 'https://video2.homepornking.com/videos/7/349/17442/872075/bb38aa3e98778aba4c57e66c04c5ca77.mp4?t=1702272313&h=321c89b17e3cc756325f8445efbf3966'

# %%
def get_video_source(html_text):
    soup = BeautifulSoup(html_text, "html.parser")
    arr = [
        s["src"].split("?")[0]
        for s in soup.find_all("source")
        if s.has_attr("src") and s["src"]
    ]
    return arr[0] if arr else ""


get_video_source(
    requests.get(
        "https://www.homepornking.com/video/7/349/17442/872075",
        headers=headers,
    ).text
)
# Out:
# 'https://video2.homepornking.com/videos/7/349/17442/872075/bb38aa3e98778aba4c57e66c04c5ca77.mp4'

# %%
soup = BeautifulSoup(
    requests.get("https://www.homepornking.com/", headers=headers).text,
    "html.parser",
)

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
# document.cookie='ttsref=noref; domain=.homepornking.com; path=/;';
#
# document.cookie='ach0=510; domain=.homepornking.com; path=/;';
#
# pe412=0;
# if (Math.tan(290) > 0)  pe477=(81536/64); else pe477=(81569*141);
# pe412+=pe477;
# if (Math.tan(330) > 0)  pe132=(1855+56); else pe132=(1905-110);
# pe412+=pe132;
# if (Math.cos(131) > 0)  pe212=(3258-73); else pe212=(3266+136);
# pe412+=pe212;
#
# document.cookie = 'ach='+pe412+'; domain=.homepornking.com; path=/;';
#
# </script>
# <title>Homemade Porn Videos, Amateur Sex Tube</title>
# <meta content="Real private nextdoor girlfriends xxx porno clips updated daily and 100% free!" name="description"/>
# <meta content="EN" name="Language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="r551r8wy8" name="trafficjunky-site-verification">
# ...

# %%
[
    [
        f"https://www.homepornking.com{str(a['href']).strip()}",
        a.find("img")["src"],
    ]
    for a in soup.find_all("a", href=True)
    if a.find("img") and a["href"].strip("/")
]
# Out:
# [['https://www.homepornking.com/go.php?u=aHR0cHM6Ly93d3cuaG9tZXBvcm5raW5nLmNvbS92aWRlby8xMS81NDgvMjczOTIvMTM2OTU5NC8/dGg9OQ==&id=92.2319332&h=6623ee7bfc53f1e25e08d0204f35d48b',
#   'https://cdn0.homepornking.com/thumbs/cl/22/1096/54783/2739157.jpg'],
#  ['https://www.homepornking.com/go.php?u=aHR0cHM6Ly93d3cuaG9tZXBvcm5raW5nLmNvbS92aWRlby8xNy84MzYvNDE3OTcvMjA4OTg1NC8/dGg9Ng==&id=92.3010455&h=7d062d81a52214e8aa0cd9e1f710181b',
#   'https://cdn0.homepornking.com/thumbs/cl/28/1410/70494/3524697.jpg'],
#  ['https://www.homepornking.com/go.php?u=aHR0cHM6Ly93d3cuaG9tZXBvcm5raW5nLmNvbS92aWRlby84LzM3OS8xODkzOC85NDY4ODAvP3RoPTE1&id=92.2090915&h=4a1e4ddd1b7806d9486706d63c15854a',
#   'https://cdn0.homepornking.com/thumbs/cl/20/991/49568/2478413.jpg'],
#  ['https://www.homepornking.com/go.php?u=aHR0cHM6Ly93d3cuaG9tZXBvcm5raW5nLmNvbS92aWRlby80LzIxMi8xMDYwOS81MzA0NTUvP3RoPTEy&id=92.1456057&h=7c98bba11d968c95c88cd92bea9cab1e',
# ...
